# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
data = pd.read_csv('breast-cancer-wisconsin.data')

# %%
column_names = ['id','Clump thickness','Uniformity of Cell size','Uniformity of Cell Shape','Marginal_Adhesion','Single_Epithelial_Cell_Size','Bare Nuclei','Bland Chromatin','Normal Nucleoli','Mitoses','Class']
data = pd.read_csv('breast-cancer-wisconsin.data',names=column_names)
data.head()
# Out:
#         id  Clump thickness  Uniformity of Cell size  \
# 0  1000025                5                        1
# 1  1002945                5                        4
# 2  1015425                3                        1
# 3  1016277                6                        8
# 4  1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal_Adhesion  Single_Epithelial_Cell_Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#   Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0           1                3                1        1      2
# ...

# %%
mapping = {2: 0, 4: 1}
data['Class'] = data['Class'].map(mapping)
data.isnull()
# Out:
#         id  Clump thickness  Uniformity of Cell size  \
# 0    False            False                    False
# 1    False            False                    False
# 2    False            False                    False
# 3    False            False                    False
# 4    False            False                    False
# ..     ...              ...                      ...
# 694  False            False                    False
# 695  False            False                    False
# 696  False            False                    False
# 697  False            False                    False
# 698  False            False                    False
#
#      Uniformity of Cell Shape  Marginal_Adhesion  Single_Epithelial_Cell_Size  \
# 0                       False              False                        False
# 1                       False              False                        False
# 2                       False              False                        False
# ...

# %%
data['Bare Nuclei'].loc[data['Bare Nuclei'] == '?'] = np.nan
data.dropna(inplace=True)
data.drop(['id'],axis = 1,inplace = True)
data.head()
# Out:
# C:\Users\pmaheria\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#    Clump thickness  Uniformity of Cell size  Uniformity of Cell Shape  \
# 0                5                        1                         1
# 1                5                        4                         4
# 2                3                        1                         1
# 3                6                        8                         8
# 4                4                        1                         1
#
#    Marginal_Adhesion  Single_Epithelial_Cell_Size Bare Nuclei  \
# 0                  1                            2           1
# 1                  5                            7          10
# ...

# %%
#this is the prediction function in order to predict the output 
def prediction (b, X):
        intercept = np.ones((X.shape[0], 1))
        X = np.c_[X, intercept]
        z = np.dot(b, X.T) 
        sigmoid = 1/(1 + np.exp(-z))
        predicted_value = [0 if i <=0.5 else 1 for i in sigmoid]        
        return predicted_value 

def newton_method(X,Y):
    iterations=150
    iteration_count=0
    conver_tol=0.000000001
    b=np.zeros(X.shape[1]+1)
    b1=[]
    intercept_X=np.ones((X.shape[0],1))
    X=np.c_[X, intercept_X]
    while((iteration_count<=iterations)):
        iteration_count+=1
        b1=b
        z = np.dot(b, X.T) 
        prob = 1/(1 + np.exp(-z))
        gradient = np.dot((Y - prob),X)
        we = prob*(1-prob)
        xP = np.array([i*j for (i,j) in zip(X,we)])
        hessian = -1*np.dot(xP.T, X)
        b = b - (np.dot(np.linalg.inv(hessian),gradient))
        co = np.linalg.norm(b-b1)
        if( co <= conver_tol):
            break
    return b,iteration_count

# %%
from sklearn import metrics 
train = 0.8
a=0
for i in range(15):
    count = np.random.rand(len(data)) < train
    a_Train = data[count]
    a_Test = data[~count]     
    y_train = a_Train["Class"].values    
    x_train = a_Train.drop(["Class","Bare Nuclei"],axis=1)    
    x_test = a_Test.drop(["Class","Bare Nuclei"],axis=1)
    y_test = a_Test["Class"].values
    b,count =newton_method(np.array(x_train), y_train)    
    pre = prediction(b,np.array(x_test))
    accuracy = metrics.accuracy_score(y_test, pre)
    a += accuracy
newton_accuracy = a/number_split 
print('Newton method with logistic regression:', newton_accuracy*100)
# Out:
# Newton method with logistic regression: 95.88834427191621

# %%
#logistic regression starts from here
import math
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score

# %%
l=LogisticRegression(n_jobs= -1)
l.fit(x_train, y_train)
y_pred = l.predict(x_test)

# %%
logi_accuracy = accuracy_score(y_test, y_pred)*100
print('Logistic regression Accurracy:',logi_accuracy)
# Out:
# Logistic regression Accurracy: 96.35036496350365
